# %%
from novel_arch import train_archs
import importlib
import torch
from novel_arch.archic_0.model import GatedGCNReactionNetworkDMPNN
from novel_arch.archic_0.directed_conv import GatedGCNConvDMPNN
from novel_arch import train
# Out:
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:50:11] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
model = GatedGCNReactionNetworkDMPNN(
        in_feats=train.dataset.feature_size,
        dbond_feat_size=16, # atom, bond -> dbond features
        node_types=["atom", "bond", "global"],

        embedding_size=24,
        gated_num_layers=3,
        gated_hidden_size=[64, 64, 64],
        gated_activation="ReLU",
        fc_num_layers=2,
        fc_hidden_size=[128, 64],
        fc_activation='ReLU',
        conv_op=GatedGCNConvDMPNN
    )

# %%
## data sample inspection
idx = 10
rxn_net = train.dataset[idx]
pr = rxn_net[0].reactions[idx].products, rxn_net[0].reactions[idx].reactants
vals = rxn_net[2]
ener = vals['value'] * vals['scaler_stdev'] + vals['scaler_mean']
print('bofa', pr, ener)
print(vals)
tout_reactions = rxn_net[0]
rxns, graphs = tout_reactions.subselect_reactions([45])
graphs[rxns[0].reactants[0]].nodes['bond'].data['feat']

# %% [markdown]
# end of model trial section

# %%
# train_archs = importlib.reload(train_archs)
train_archs.archic_0()
# Out:
# # Epoch     Loss         TrainAcc        ValAcc
# /home/pmistry/.conda/envs/bndnet/lib/python3.11/site-packages/dgl/backend/pytorch/tensor.py:449: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), (
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 # train_archs = importlib.reload(train_archs)
# ----> 2 train_archs.archic_0()
#
# File ~/Documents/research/GNNpredict/novel_arch/train_archs.py:25, in archic_0()
#       8 model = GatedGCNReactionNetworkDMPNN(
#       9     in_feats=train.dataset.feature_size,
#      10     dbond_feat_size=16, # atom, bond -> dbond features
#    (...)
#      20     conv_op=GatedGCNConvDMPNN
#      21 )
#      23 # print("params:", sum(p.numel() for p in model.parameters()))
# ---> 25 train.train_for_epochs_w_Test_MAE(model, 'archic-0_chkpoint.pkl')
#
# File ~/Documents/research/GNNpredict/novel_arch/train.py:119, in train_for_epochs_w_Test_MAE(model, checkpoint_name)
#     115 print("# Epoch     Loss         TrainAcc        ValAcc")
#     116 for epoch in range(num_epochs):
#     117
#     118     # train on training set
# --> 119     loss, train_acc = train( optimizer, model, feature_names, train_loader, loss_func, metric)
#     121     # evaluate on validation set
#     122     val_acc = evaluate(model, feature_names, val_loader, metric)
#
# File ~/Documents/research/GNNpredict/novel_arch/train.py:66, in train(optimizer, model, nodes, data_loader, loss_fn, metric_fn)
#      63 target = label["value"]
#      64 stdev = label["scaler_stdev"]
# ---> 66 pred = model(batched_graph, feats, label["reaction"])
#      67 pred = pred.view(-1)
#      69 loss = loss_fn(pred, target)
#
# File ~/.conda/envs/bndnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/model.py:125, in GatedGCNReactionNetworkDMPNN.forward(self, graph, feats, reactions, norm_atom, norm_bond)
#     116     feats = layer(graph, feats, norm_atom, norm_bond)
#     118 # HERE: < ------------------------- !!
#     119
#     120 # reverse dmpnn to atom + global features
#    (...)
#     123 # convert mol graphs to reaction graphs by subtracting reactant feats from
#     124 # products feats
# --> 125 graph, feats = mol_graph_to_rxn_graph(graph, feats, reactions)
#     127 # readout layer
#     128 feats = self.readout_layer(graph, feats)
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/model.py:251, in mol_graph_to_rxn_graph(graph, feats, reactions)
#     244 has_bonds = {
#     245     # we support only one reactant now, so no it is assumed always to have bond
#     246     "reactants": [True for _ in reactants],
#     247     "products": [True if len(mp) > 0 else False for mp in rxn.bond_mapping],
#     248 }
#     249 mappings = {"atom": rxn.atom_mapping_as_list, "bond": rxn.bond_mapping_as_list}
# --> 251 g, fts = create_rxn_graph(
#     252     reactants, products, mappings, has_bonds, tuple(feats.keys())
#     253 )
#     254 reaction_graphs.append(g)
#     255 reaction_feats.append(fts)
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/model.py:325, in create_rxn_graph(reactants, products, mappings, has_bonds, ntypes, ft_name)
#     322     products_ft = torch.sum(products_ft, dim=0, keepdim=True)
#     323 else:
#     324     # reorder products_ft such that atoms (bonds) have the same order as reactants
# --> 325     assert len(products_ft) == len(mappings[nt]), (
#     326         f"products_ft ({len(products_ft)}) and mappings[{nt}] "
#     327         f"({len(mappings[nt])}) have different length"
#     328     )
#     329     products_ft = products_ft[mappings[nt]]
#     331 feats[nt] = products_ft - reactants_ft
#
# KeyError: 'd_bond'

# %%
from novel_arch import train

# %%
rxn = train.dataset[0][0]

# %%
rxn.molecules[1].nodes['atom'].data.update({'halp': torch.zeros([4,4])})

# %%
rxn.molecules[1].nodes['atom'].data['feat']

# %% [markdown]
# ndata (or edata) gives a full dict of all node type features with feat name
# nodes[name].data[feat] gives full dict of all node types with this feature name

# %%
rxn.molecules[1].ndata['feat']

# %%
rxn.molecules[1].edges['b2g'].data

# %%
rxn.molecules[1].num_nodes('atom')

# %%
len(train.dataset[2][0].reactions)

# %%
train.dataset[5][0].reactions[0].reactants

# %%
full = train.dataset[6][0].subselect_reactions([1])
reaction = full[0][0]
reaction.products
full[1]
reaction.init_products

# %%
train.trainset[0][0].reactions[136].products

# %%
train.trainset[0][0].molecules
