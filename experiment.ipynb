# %%
from novel_arch import train_archs
import importlib
import torch
# Out:
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:15:17] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
train_archs = importlib.reload(train_archs)
train_archs.archic_0()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 train_archs = importlib.reload(train_archs)
# ----> 2 train_archs.archic_0()
#
# File ~/Documents/research/GNNpredict/novel_arch/train_archs.py:8, in archic_0()
#       7 def archic_0(): # this is where i am playing around right now
# ----> 8     model = GatedGCNReactionNetworkDMPNN(
#       9         in_feats=train.dataset.feature_size,
#      10         embedding_size=24,
#      11         gated_num_layers=3,
#      12         gated_hidden_size=[64, 64, 64],
#      13         gated_activation="ReLU",
#      14         fc_num_layers=2,
#      15         fc_hidden_size=[128, 64],
#      16         fc_activation='ReLU',
#      17         conv_op=GatedGCNConvDMPNN
#      18     )
#      20     train.train_for_epochs_w_Test_MAE(model, 'archic-0_chkpoint.pkl')
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/model.py:62, in GatedGCNReactionNetworkDMPNN.__init__(self, in_feats, embedding_size, gated_num_layers, gated_hidden_size, gated_num_fc_layers, gated_graph_norm, gated_batch_norm, gated_activation, gated_residual, gated_dropout, num_lstm_iters, num_lstm_layers, set2set_ntypes_direct, fc_num_layers, fc_hidden_size, fc_batch_norm, fc_activation, fc_dropout, outdim, conv_op)
#      16 def __init__(
#      17     self,
#      18     in_feats,
#    (...)
#      37     conv_op = None,
#      38 ):
#      39     super().__init__(
#      40         in_feats,
#      41         embedding_size=32,
#    (...)
#      59         conv_op=conv_op,
#      60     )
# ---> 62     self.graph_featurizer = GrambowFeaturizer()
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/feature_transform.py:9, in GrambowFeaturizer.__init__(self)
#       6 def __init__(self):
#       7     super().__init__()
# ----> 9     assert False
#
# AssertionError:

# %%
from novel_arch import train
# Out:
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero
# [14:11:31] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
rxn = train.dataset[0][0]

# %%
rxn.molecules[1].nodes['atom'].data.update({'halp': torch.zeros([4,4])})

# %%
rxn.molecules[1].nodes['atom'].data['feat']
# Out:
# tensor([[ 0.1397, -0.1525,  0.9676, -0.7002, -0.1656, -0.7194, -0.2676,  1.7971,
#          -0.0748, -0.0748, -0.1083,  0.0000,  0.0000],
#         [ 0.1397, -0.1525, -0.5003,  1.4281, -0.1656, -0.7194, -0.2676, -0.5564,
#          -0.0748, -0.0748, -0.1083,  0.0000,  0.0000],
#         [-0.8672, -0.1525, -0.5003, -0.7002, -0.1656, -0.7194, -0.2676,  1.7971,
#          -0.0748, -0.0748, -0.1083,  0.0000,  0.0000],
#         [-0.8672, -0.1525, -0.5003, -0.7002, -0.1656,  1.3900, -0.2676, -0.5564,
#          -0.0748, -0.0748, -0.1083,  0.0000,  0.0000]])

# %% [markdown]
# ndata (or edata) gives a full dict of all node type features with feat name
# nodes[name].data[feat] gives full dict of all node types with this feature name

# %%
rxn.molecules[1].ndata['feat']
# Out:
# {'atom': tensor([[ 0.1397, -0.1525,  0.9676, -0.7002, -0.1656, -0.7194, -0.2676,  1.7971,
#           -0.0748, -0.0748, -0.1083,  0.0000,  0.0000],
#          [ 0.1397, -0.1525, -0.5003,  1.4281, -0.1656, -0.7194, -0.2676, -0.5564,
#           -0.0748, -0.0748, -0.1083,  0.0000,  0.0000],
#          [-0.8672, -0.1525, -0.5003, -0.7002, -0.1656, -0.7194, -0.2676,  1.7971,
#           -0.0748, -0.0748, -0.1083,  0.0000,  0.0000],
#          [-0.8672, -0.1525, -0.5003, -0.7002, -0.1656,  1.3900, -0.2676, -0.5564,
#           -0.0748, -0.0748, -0.1083,  0.0000,  0.0000]]),
#  'bond': tensor([[-0.1580, -0.0775, -0.0775, -0.1122,  0.0000,  0.0000, -0.3513],
#          [-0.1580, -0.0775, -0.0775, -0.1122,  0.0000,  0.0000, -0.3513],
#          [-0.1580, -0.0775, -0.0775, -0.1122,  0.0000,  0.0000, -0.3513]]),
#  'global': tensor([[-1.1222, -1.1340, -0.9343,  1.2685, -0.8445, -0.5007]])}

# %%
rxn.molecules[1].edges['b2g'].data
# Out:
# {}

# %%
rxn.molecules[1].num_nodes('atom')
# Out:
# 4

# %%
len(train.dataset[2][0].reactions)
# Out:
# 200

# %%
train.dataset[5][0].reactions[0].reactants
# Out:
# [1]

# %%
full = train.dataset[6][0].subselect_reactions([1])
reaction = full[0][0]
reaction.products
full[1]
reaction.init_products
# Out:
# [451, 6]

# %%
train.trainset[0][0].reactions[136].products
# Out:
# [225, 175]

# %%
train.trainset[0][0].molecules
