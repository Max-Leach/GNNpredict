# %%
from novel_arch import train_archs
import importlib
import torch
# Out:
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero
# [15:44:00] Warning: molecule is tagged as 3D, but all Z coords are zero

# %%
# train_archs = importlib.reload(train_archs)
train_archs.archic_0()
# Out:
# # Epoch     Loss         TrainAcc        ValAcc
# /home/pmistry/.conda/envs/bndnet/lib/python3.11/site-packages/dgl/backend/pytorch/tensor.py:449: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), (
# ---------------------------------------------------------------------------
# DGLError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 # train_archs = importlib.reload(train_archs)
# ----> 2 train_archs.archic_0()
#
# File ~/Documents/research/GNNpredict/novel_arch/train_archs.py:24, in archic_0()
#       8 model = GatedGCNReactionNetworkDMPNN(
#       9     in_feats=train.dataset.feature_size,
#      10     dbond_feat_size=8, # atom, bond -> dbond features
#    (...)
#      19     conv_op=GatedGCNConvDMPNN
#      20 )
#      22 # print("params:", sum(p.numel() for p in model.parameters()))
# ---> 24 train.train_for_epochs_w_Test_MAE(model, 'archic-0_chkpoint.pkl')
#
# File ~/Documents/research/GNNpredict/novel_arch/train.py:119, in train_for_epochs_w_Test_MAE(model, checkpoint_name)
#     115 print("# Epoch     Loss         TrainAcc        ValAcc")
#     116 for epoch in range(num_epochs):
#     117
#     118     # train on training set
# --> 119     loss, train_acc = train( optimizer, model, feature_names, train_loader, loss_func, metric)
#     121     # evaluate on validation set
#     122     val_acc = evaluate(model, feature_names, val_loader, metric)
#
# File ~/Documents/research/GNNpredict/novel_arch/train.py:66, in train(optimizer, model, nodes, data_loader, loss_fn, metric_fn)
#      63 target = label["value"]
#      64 stdev = label["scaler_stdev"]
# ---> 66 pred = model(batched_graph, feats, label["reaction"])
#      67 pred = pred.view(-1)
#      69 loss = loss_fn(pred, target)
#
# File ~/.conda/envs/bndnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/model.py:93, in GatedGCNReactionNetworkDMPNN.forward(self, graph, feats, reactions, norm_atom, norm_bond)
#      91 # gated layer
#      92 for layer in self.gated_layers:
# ---> 93     feats = layer(graph, feats, norm_atom, norm_bond)
#      95 # convert mol graphs to reaction graphs by subtracting reactant feats from
#      96 # products feats
#      97 graph, feats = mol_graph_to_rxn_graph(graph, feats, reactions)
#
# File ~/.conda/envs/bndnet/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/research/GNNpredict/novel_arch/archic_0/directed_conv.py:201, in GatedGCNConvDMPNN.forward(self, g, feats, norm_atom, norm_bond)
#     199 g.nodes["d_bond"].data.update({"He": self.H(e)})
#     200 g.nodes["global"].data.update({"Iu": self.I(u)})
# --> 201 g.multi_update_all(
#     202     {
#     203         # "a2g": (fn.copy_u("Gh", "m"), fn.mean("m", "u")),  # G * (mean_i h_i)
#     204         "db2g": (fn.copy_u("He", "m"), fn.mean("m", "u")),  # H * (mean_ij e_ij)
#     205         "g2g": (fn.copy_u("Iu", "m"), fn.sum("m", "u")),  # I * u
#     206     },
#     207     "sum",
#     208 )
#     209 u = g.nodes["global"].data["u"]
#     210 # do not apply batch norm if it there is only one graph
#
# File ~/.conda/envs/bndnet/lib/python3.11/site-packages/dgl/heterograph.py:5247, in DGLGraph.multi_update_all(self, etype_dict, cross_reducer, apply_node_func)
#    5244 merge_order = defaultdict(list)
#    5245 for etype, args in etype_dict.items():
# -> 5247     etid = self.get_etype_id(etype)
#    5248     _, dtid = self._graph.metagraph.find_edge(etid)
#    5249     args = pad_tuple(args, 3)
#
# File ~/.conda/envs/bndnet/lib/python3.11/site-packages/dgl/heterograph.py:1411, in DGLGraph.get_etype_id(self, etype)
#    1406         raise DGLError(
#    1407             "Edge type name must be specified if there are more than one "
#    1408             "edge types."
#    1409         )
#    1410     return 0
# -> 1411 etid = self._etypes_invmap.get(self.to_canonical_etype(etype), None)
#    1412 if etid is None:
#    1413     raise DGLError('Edge type "{}" does not exist.'.format(etype))
#
# File ~/.conda/envs/bndnet/lib/python3.11/site-packages/dgl/heterograph.py:1289, in DGLGraph.to_canonical_etype(self, etype)
#    1287 ret = self._etype2canonical.get(etype, None)
#    1288 if ret is None:
# -> 1289     raise DGLError('Edge type "{}" does not exist.'.format(etype))
#    1290 if len(ret) == 0:
#    1291     raise DGLError(
#    1292         'Edge type "%s" is ambiguous. Please use canonical edge type '
#    1293         "in the form of (srctype, etype, dsttype)" % etype
#    1294     )
#
# DGLError: Edge type "g2g" does not exist.

# %%
from novel_arch import train

# %%
rxn = train.dataset[0][0]

# %%
rxn.molecules[1].nodes['atom'].data.update({'halp': torch.zeros([4,4])})

# %%
rxn.molecules[1].nodes['atom'].data['feat']

# %% [markdown]
# ndata (or edata) gives a full dict of all node type features with feat name
# nodes[name].data[feat] gives full dict of all node types with this feature name

# %%
rxn.molecules[1].ndata['feat']

# %%
rxn.molecules[1].edges['b2g'].data

# %%
rxn.molecules[1].num_nodes('atom')

# %%
len(train.dataset[2][0].reactions)

# %%
train.dataset[5][0].reactions[0].reactants

# %%
full = train.dataset[6][0].subselect_reactions([1])
reaction = full[0][0]
reaction.products
full[1]
reaction.init_products

# %%
train.trainset[0][0].reactions[136].products

# %%
train.trainset[0][0].molecules
